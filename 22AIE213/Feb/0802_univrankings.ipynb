# %% [markdown]
# ## THE World University Rankings 2016-2024

# %% [markdown]
# ### Read the data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df = pd.read_csv('univ_rank.csv', encoding='latin-1')

# %%
df.head()
# Out:
#    Rank                                   Name         Country  \
# 0   1.0     California Institute of Technology   United States
# 1   2.0                   University of Oxford  United Kingdom
# 2   3.0                    Stanford University   United States
# 3   4.0                University of Cambridge  United Kingdom
# 4   5.0  Massachusetts Institute of Technology   United States
#
#    Student Population  Students to Staff Ratio International Students  \
# 0                2243                      6.9                    26%
# 1               19920                     11.6                    34%
# 2               15596                      7.8                    22%
# 3               18810                     11.8                    34%
# 4               11074                      9.0                    33%
#
#   Female to Male Ratio  Overall Score  Teaching  Research Environment  \
# 0              33 : 67           95.2      95.6                  97.6
# ...

# %%
df_1000 = df.head(1000)

# %%
df_1000.head(20)
# Out:
#     Rank                                   Name         Country  \
# 0    1.0     California Institute of Technology   United States
# 1    2.0                   University of Oxford  United Kingdom
# 2    3.0                    Stanford University   United States
# 3    4.0                University of Cambridge  United Kingdom
# 4    5.0  Massachusetts Institute of Technology   United States
# 5    6.0                     Harvard University   United States
# 6    7.0                   Princeton University   United States
# 7    8.0                Imperial College London  United Kingdom
# 8    9.0                             ETH Zurich     Switzerland
# 9   10.0              The University of Chicago   United States
# 10  11.0               Johns Hopkins University   United States
# 11  12.0                        Yale University   United States
# 12  13.0     University of California, Berkeley   United States
# 13  14.0                                    UCL  United Kingdom
# ...

# %%
df.isna().sum()
# Out:
# Rank                         0
# Name                         0
# Country                      0
# Student Population           0
# Students to Staff Ratio      0
# International Students       0
# Female to Male Ratio       591
# Overall Score                0
# Teaching                     0
# Research Environment         0
# Research Quality             0
# Industry Impact              0
# International Outlook        0
# Year                         0
# dtype: int64

# %%
print(df.Country.value_counts())
# Out:
# Country
# United States             1506
# Japan                      882
# United Kingdom             869
# China                      674
# India                      495
#                           ...
# Mauritius                    2
# Armenia                      1
# North Macedonia              1
# Bosnia and Herzegovina       1
# Kosovo                       1
# Name: count, Length: 108, dtype: int64

# %%
# Top 10 countries with the most universities in the top 1000 (show value counts in barplot)
df_1000.Country.value_counts().head(10).plot(kind='bar')
print(df_1000.Country.value_counts().head(10))
# Out:
# Country
# United States     209
# United Kingdom    110
# Germany            59
# Japan              43
# China              41
# Australia          39
# Italy              36
# Canada             33
# France             31
# South Korea        28
# Name: count, dtype: int64

# %%
#Interrelation between the rank and the number of students(adjust the size of the points according to the number of students)
df_1000.plot(kind='scatter', x='Country', y='Student Population', s=df_1000['Student Population']/1000)
# Out:
# <Axes: xlabel='Country', ylabel='Student Population'>

# %%
df.fillna('Unknown', inplace=True)

# %%
df.isna().sum()
# Out:
# Rank                       0
# Name                       0
# Country                    0
# Student Population         0
# Students to Staff Ratio    0
# International Students     0
# Female to Male Ratio       0
# Overall Score              0
# Teaching                   0
# Research Environment       0
# Research Quality           0
# Industry Impact            0
# International Outlook      0
# Year                       0
# dtype: int64
